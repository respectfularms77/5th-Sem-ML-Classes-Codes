# %%
#1st Pandas and then Seaborn
import pandas as pd
import seaborn as sns
tips = sns.load_dataset("tips")
print("Head/Staring Values: \n",tips.head(7))
print("\n\nInfo about Dataset: \n",tips.info())
print("\n\nDescription about Dataset: \n",tips.describe())
# Out:
# Head/Staring Values:
#     total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# ...

# %%
#Handling Missing values
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Name': ['Arpit', 'Arpan', np.nan , 'Ankan'],
    'Age': [20, 22, 24, np.nan],
    'Quote': ['A', np.nan, 'K', 'N'],
    'City': ['Delhi', 'Mumbai', np.nan , 'Pune'],  
    'Salary': [50000, np.nan, 75000, 50000]      
}
df = pd.DataFrame(data)


# print(df.info(),end="\n\n")
# print(df.describe(),end="\n\n")
# print(df.isnull(),end="\n\n")
# print(df.isnull().any(axis=0),end="\n\n")
# print(df.isnull().any(axis=1),end="\n\n")

df_filled=df.fillna({'Age':df['Age'].mean()})
# # print(df_filled)                                    #-------> Filled the Missing Val in Age with Mean of Age's

# df_copy1 = df_filled.copy()
# del df_copy1['Quote']
# print(df_copy1)                                       #-------> Deleted the Coloumn Quote of the Copy

df_copy2 = df_filled.copy()

print(df_copy2)
df_copy3 = df_filled.copy()
names_col = df_copy3.pop('Name')
print(df_copy3)
print(names_col)
df_filled.plot(kind='box', figsize=(6,4), title='BoxPlot of Manually Created Students')
plt.show()


#Boxplot
plt.figure(figsize=(8,5))
sns.boxplot(data=tips[['total_bill','tip','size']])
plt.title('BoxPlot of Tips Dataset')
plt.show()
# Out:
#     Name   Age Quote    City   Salary
# 0  Arpit  20.0     A   Delhi  50000.0
# 1  Arpan  22.0   NaN  Mumbai      NaN
# 2    NaN  24.0     K     NaN  75000.0
# 3  Ankan  22.0     N    Pune  50000.0
#     Age Quote    City   Salary
# 0  20.0     A   Delhi  50000.0
# 1  22.0   NaN  Mumbai      NaN
# 2  24.0     K     NaN  75000.0
# 3  22.0     N    Pune  50000.0
# 0    Arpit
# 1    Arpan
# 2      NaN
# 3    Ankan
# Name: Name, dtype: object
