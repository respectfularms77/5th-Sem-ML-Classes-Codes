# %%
#Libraries: numpy, matplotlib, sklearn.neighbors

import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

print("\n --- K-Nearest Neighbors Exampless -----")

# STEP 1 : Define Training Data
X = np.array([[1,2],[2,3],[3,3],[6,5],[7,7], [8,6]])      
y = np.array([0,0,0,1,1,1])

# STEP 2 : Create and Train Model
k=3      #Number of Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors=k)             #Intilise the KNN classifer
knn.fit(X, y)               #Train the Classifier using the Dataset(X, y)

#STEP 3 : Predict for a New Sample
sample = np.array([[3,5]])        # New Data Point to classify
predicted_class = knn.predict(sample)[0]
print("Predicted Class for [3,5]:", predicted_class)

# STEP 4: Plot Decision Boundary
h=0.1              #Step size for mesh grid
x_min, x_max = X[:,0].min() - 1, X[:,0].max() + 1
y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

#Predict class for each Grid Point
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

#Create decision boundary with filled Contours
plt.contourf(xx, yy, Z, alpha=0.3, cmap = plt.cm.Paired)

#Plot training data points
plt.scatter(X[:,0], X[:,1], c=y, edgecolor = 'k', s=80, cmap=plt.cm.Paired, label = "Training Points")

#Highlight the test Sample
plt.scatter(sample[0,0], sample[0,1], c='red', edgecolor='black', s=120, marker='*', label="Test Sample[3,5]")

# Add annotation and labels
plt.text(1,1.5, "Class 0 region", fontsize=10, color='blue')
plt.text(6.2,4.2, "Class 1 region", fontsize=10, color='darkgreen')

plt.title(f"KNN Decision BOundary (k={k})", fontsize=13)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
#  --- K-Nearest Neighbors Exampless -----
# Predicted Class for [3,5]: 0
